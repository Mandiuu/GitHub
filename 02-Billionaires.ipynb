# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.
#
# > Again, **don't use ChatGPT for this assignment.** You should be able to memorize the most basic parts of pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** .

# %%
import pandas as pd

# %%
pip install openpyxl --upgrade
# Out:
# Requirement already satisfied: openpyxl in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`. Trying `read_excel` the first time will probably not work, you'll get an error message. Be sure to read the error carefully: *you probably need to install a new library before it will work, and the error tells you what the library is named*. You *might* need to do `Kernel > Restart Kernel...` and run the notebook again from the top in order to get it to work.

# %%
df = pd.read_excel('richpeople.xlsx')

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df.head()
# Out:
#    year                          name  rank           citizenship countrycode  \
# 0  2014          A. Jerrold Perenchio   663         United States         USA
# 1  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 2  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 3  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 4  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 0                2.6  self-made            executive   male  83.0  ...
# 1                2.5  inherited            inherited   male   NaN  ...
# 2                4.8  inherited            inherited   male   NaN  ...
# 3                2.4  self-made    self-made finance   male   NaN  ...
# 4                1.2  self-made  founder non-finance   male  54.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 0  former chairman and CEO       1955.0          NaN
# 1                 relation       1930.0          NaN
# 2                 relation       1960.0          NaN
# 3                  founder       1957.0          NaN
# 4                  founder       1988.0          NaN
#
#               sourceofwealth                                           notes  \
# 0      television, Univision  represented Marlon Brando and Elizabeth Taylor
# 1  auto dealers, investments    company split between him and cousin in 2000
# 2                diversified                           inherited from father
# 3                    banking                                             NaN
# 4       sugar, flour, cement                                             NaN
#
#    notes2                                           source  \
# 0     NaN     http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1     NaN    http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2     NaN    http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3     NaN       http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4     NaN  http://www.forbes.com/profile/abdulsamad-rabiu/
#
#                                             source_2  \
# 0  http://www.forbes.com/profile/a-jerrold-perenc...
# 1  http://www.al-futtaim.ae/content/groupProfile.asp
# 2      http://www.alghurair.com/about-us/our-history
# 3  http://www.alrajhibank.com.sa/ar/investor-rela...
# 4  http://www.bloomberg.com/research/stocks/priva...
#
#                                             source_3 source_4
# 0  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3  http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 4                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
richest= df.sort_values('networthusbillion', ascending=False).head(10)
richest
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 339   2014        David Koch     6  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# 79                 64.0  self-made       founder non-finance    male  77.0
# 1562               58.2  self-made       founder non-finance    male  83.0
# 862                48.0  self-made       founder non-finance    male  69.0
# 339                40.0  inherited                 inherited    male  73.0
# 247                40.0  inherited                 inherited    male  78.0
# 1364               38.0  self-made         self-made finance    male  80.0
# 280                36.7  inherited                 inherited  female  59.0
# 724                34.7  inherited                 inherited    male  66.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus      sourceofwealth  \
# 184   ...               founder       1975.0          NaN           Microsoft
# 226   ...               founder       1990.0          NaN             telecom
# 79    ...               founder       1975.0          NaN              retail
# 1562  ...               founder       1839.0          NaN  Berkshire Hathaway
# 862   ...               founder       1977.0          NaN              Oracle
# 339   ...              relation       1940.0          NaN         diversified
# 247   ...              relation       1940.0          NaN         diversified
# 1364  ...               founder       1952.0          NaN             casinos
# 280   ...              relation       1962.0          NaN            Wal-Mart
# 724   ...              relation       1962.0          NaN            Wal-Mart
#
#                       notes  notes2  \
# 184                     NaN     NaN
# 226                     NaN     NaN
# 79                      NaN     NaN
# 1562                    NaN     NaN
# 862                     NaN     NaN
# 339   inherited from father     NaN
# 247   inherited from father     NaN
# 1364                    NaN     NaN
# 280                   widow     NaN
# 724   inherited from father     NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 339   http://www.kochind.com/About_Koch/History_Time...
# 247   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 184                                                 NaN      NaN      NaN
# 226                                                 NaN      NaN      NaN
# 79                                                  NaN      NaN      NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 862   http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 339                                                 NaN      NaN      NaN
# 247                                                 NaN      NaN      NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 280                                                 NaN      NaN      NaN
# 724                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 4a) How many male billionaires are there compared to the number of female billionares?
#
# > **TIP:** This is not a `.groupby`

# %%
df['gender'].value_counts()
# Out:
# gender
# male      1473
# female     180
# Name: count, dtype: int64

# %% [markdown]
# ## 4b) What percent is that?
#
# > **TIP:** Doing percentages with the answer to `4a` is so common that there's an extra parameter to automatically calculate it. Look at the documentation!

# %%
df['gender'].value_counts(normalize=True)*100
# Out:
# gender
# male      89.110708
# female    10.889292
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4c) Is the average wealth different for a female billionaire as compared to a male billionaire?
#
# > **TIP:** This one *does* use `.groupby`. You can pick what 'average' means in this context.

# %%
df.groupby("gender")['networthusbillion'].mean()
# Out:
# gender
# female    3.920556
# male      3.902716
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 5a) What is the most common source/type of wealth?

# %%
df.typeofwealth.value_counts()
# Out:
# typeofwealth
# inherited                   506
# founder non-finance         467
# self-made finance           344
# privatized and resources    192
# executive                   142
# Name: count, dtype: int64

# %% [markdown]
# ## 5b) Is the most common source/type of wealth different between men and women?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together??? You could also do this as two separate cells where you calculate it separately for men and women.
# >
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
df.groupby("gender")['typeofwealth'].value_counts(normalize=True) * 100
# Out:
# gender  typeofwealth
# female  inherited                   78.888889
#         founder non-finance         11.666667
#         executive                    3.333333
#         self-made finance            3.333333
#         privatized and resources     2.777778
# male    founder non-finance         30.319511
#         inherited                   24.745071
#         self-made finance           22.977566
#         privatized and resources    12.712441
#         executive                    9.245411
# Name: proportion, dtype: float64

# %% [markdown]
# ## 6a) What companies have the most billionaires? Let's see the top five.
#
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.

# %%
companiesbill = df.sort_values(by='company', ascending=True).head(5)
companiesbill
# Out:
#       year                  name  rank    citizenship countrycode  \
# 1004  2014       Mark Zuckerberg    21  United States         USA
# 931   2014      Liselott Persson   305         Sweden         SWE
# 1395  2014        Stefan Persson    12         Sweden         SWE
# 896   2014  Leonardo Del Vecchio    38          Italy         ITA
# 563   2014       Hans Peter Wild   520        Germany         DEU
#
#       networthusbillion   selfmade         typeofwealth  gender   age  ...  \
# 1004               28.5  self-made  founder non-finance    male  29.0  ...
# 931                 4.8  inherited            inherited  female  64.0  ...
# 1395               34.4  inherited            inherited    male  66.0  ...
# 896                19.2  self-made  founder non-finance    male  78.0  ...
# 563                 3.1  inherited            inherited    male  72.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus     sourceofwealth  \
# 1004               founder       2004.0          NaN           Facebook
# 931              inherited       1947.0          NaN                H&M
# 1395              relation       1947.0          NaN                H&M
# 896                founder       1961.0          NaN         eyeglasses
# 563               relation       1931.0          NaN  Wild Flavors GmbH
#
#                        notes          notes2  \
# 1004                     NaN             NaN
# 931    inherited from father  holds 5% stake
# 1395   inherited from father             NaN
# 896                      NaN             NaN
# 563   inherited from parents             NaN
#
#                                                  source  \
# 1004     http://www.forbes.com/profile/mark-zuckerberg/
# 931     http://www.forbes.com/profile/liselott-persson/
# 1395      http://www.forbes.com/profile/stefan-persson/
# 896   http://en.wikipedia.org/wiki/Leonardo_Del_Vecchio
# 563         http://en.wikipedia.org/wiki/Wild_(company)
#
#                                                source_2 source_3 source_4
# 1004                                                NaN      NaN      NaN
# 931                                                 NaN      NaN      NaN
# 1395                                                NaN      NaN      NaN
# 896   http://www.forbes.com/profile/leonardo-del-vec...      NaN      NaN
# 563                                                 NaN      NaN      NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 6b) Graph those top 5 as a horizontal bar graph. Make the largest bar be at the top of the graph.
#
# > **TIP:** Just try to throw `.plot()` on the end??
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/carlamandiola/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
companiesbill.plot (x ='company', y ='networthusbillion', kind='bar')
# Out:
# <Axes: xlabel='company'>

# %% [markdown]
# ## 7) How much money do these top 5 billionaires have in total?
#
# > **TIP:** for multiple conditions, you can't use `or` and `and`. In pandas, `|` means *or* and `&` means *and*.
# >
# > **TIP:** Checking multiple conditions can be done two ways.
# > - `(df.colname == 'A') | (df.colname == 'B')`
# > - `df.colname.isin(['A', 'B'])`

# %%
billionaires = df.sort_values('networthusbillion', ascending=False)

# %%
billionaires = billionaires.sort_values(by='networthusbillion', ascending=False)

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
countries = df.sort_values(by='countrycode', ascending=True).head(10)
countries2 = countries.sort_values(by='networthusbillion', ascending=True).head(10) 
countries2
# Out:
#       year                             name  rank           citizenship  \
# 34    2014                 Alberto Roemmers  1372             Argentina
# 986   2014   Maria Ines de Lafuente Lacroze  1372             Argentina
# 540   2014           Gregorio Perez Companc  1154             Argentina
# 404   2014                Eduardo Eurnekian   931             Argentina
# 1     2014               Abdulla Al Futtaim   687  United Arab Emirates
# 1325  2014                  Saif Al Ghurair   609  United Arab Emirates
# 646   2014                Isabel dos Santos   408                Angola
# 969   2014                 Majid Al Futtaim   328  United Arab Emirates
# 2     2014     Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 220   2014  Carlos and Alejandro Bulgheroni   256             Argentina
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# 34           ARG                1.2  inherited                 inherited
# 986          ARG                1.2  inherited                 inherited
# 540          ARG                1.5  inherited                 inherited
# 404          ARG                1.9  self-made         self-made finance
# 1            ARE                2.5  inherited                 inherited
# 1325         ARE                2.8  inherited                 inherited
# 646          AGO                3.7  self-made  privatized and resources
# 969          ARE                4.5  self-made         self-made finance
# 2            ARE                4.8  inherited                 inherited
# 220          ARG                5.5  inherited                 inherited
#
#       gender   age  ... relationshiptocompany foundingdate gdpcurrentus  \
# 34      male  56.0  ...              relation       1921.0          NaN
# 986   female  69.0  ...              relation       1926.0          NaN
# 540     male  78.0  ...              relation       1968.0          NaN
# 404     male  81.0  ...               founder       1988.0          NaN
# 1       male   NaN  ...              relation       1930.0          NaN
# 1325    male   NaN  ...              relation       1960.0          NaN
# 646   female  40.0  ...               founder       1997.0          NaN
# 969     male   NaN  ...               founder       1995.0          NaN
# 2       male   NaN  ...              relation       1960.0          NaN
# 220     male   NaN  ...              relation       1948.0          NaN
#
#                  sourceofwealth  \
# 34              pharmaceuticals
# 986     cement firm inheritance
# 540                 oil and gas
# 404       airports, investments
# 1     auto dealers, investments
# 1325                diversified
# 646                 investments
# 969         real estate, retail
# 2                   diversified
# 220                 oil and gas
#
#                                                   notes         notes2  \
# 34                                inherited from father            NaN
# 986                               inherited from mother  only daughter
# 540                               inherited from father            NaN
# 404   signed 30 year concession agreement with Armen...            NaN
# 1          company split between him and cousin in 2000            NaN
# 1325                              inherited from father            NaN
# 646   daughter of Angolan president Jose Eduaredo do...            NaN
# 969                                                 NaN            NaN
# 2                                 inherited from father            NaN
# 220                               inherited from family            NaN
#
#                                                  source  \
# 34      http://www.forbes.com/profile/alberto-roemmers/
# 986   http://www.forbes.com/profile/maria-ines-de-la...
# 540   http://en.wikipedia.org/wiki/Gregorio_P%C3%A9r...
# 404      http://en.wikipedia.org/wiki/Eduardo_Eurnekian
# 1         http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 1325      http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 646   The Philadelphia Daily News January 6, 2016 We...
# 969   http://en.wikipedia.org/wiki/Majid_Al_Futtaim_...
# 2         http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 220      http://en.wikipedia.org/wiki/Carlos_Bulgheroni
#
#                                                source_2  \
# 34                                                  NaN
# 986             http://en.wikipedia.org/wiki/Loma_Negra
# 540   http://www.forbes.com/profile/gregorio-perez-c...
# 404    http://www.forbes.com/profile/eduardo-eurnekian/
# 1     http://www.al-futtaim.ae/content/groupProfile.asp
# 1325      http://www.alghurair.com/about-us/our-history
# 646    http://www.forbes.com/profile/isabel-dos-santos/
# 969   http://www.majidalfuttaim.com/about-us/overvie...
# 2         http://www.alghurair.com/about-us/our-history
# 220   http://www.forbes.com/profile/carlos-and-aleja...
#
#                                                source_3  \
# 34                                                  NaN
# 986                                                 NaN
# 540                                                 NaN
# 404   Jerusalem Post October 1, 2015 Thursday The un...
# 1                                                   NaN
# 1325                                                NaN
# 646   http://www.forbes.com/sites/kerryadolan/2013/0...
# 969     http://www.forbes.com/profile/majid-al-futtaim/
# 2                                                   NaN
# 220                                                 NaN
#
#                                                source_4
# 34                                                  NaN
# 986                                                 NaN
# 540                                                 NaN
# 404                                                 NaN
# 1                                                   NaN
# 1325                                                NaN
# 646                                                 NaN
# 969   The Press (Christchurch, New Zealand) April 29...
# 2                                                   NaN
# 220                                                 NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 9a) How old is an average billionaire?

# %%
df['age'].mean()
# Out:
# 63.34213836477988

# %% [markdown]
# ## 9b) How old are self-made billionaires compared to non self-made billionaires?

# %%
df.groupby('selfmade')['age'].mean()
# Out:
# selfmade
# inherited    64.962185
# self-made    62.625899
# Name: age, dtype: float64

# %% [markdown]
# ## 10a) Who are the three youngest billionaires? Who are the three oldest?

# %%
df.sort_values('age', ascending=True).head(3)
# Out:
#       year              name  rank    citizenship countrycode  \
# 1172  2014       Perenna Kei  1284      Hong Kong         HKG
# 397   2014  Dustin Moskovitz   202  United States         USA
# 1004  2014   Mark Zuckerberg    21  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  ...  \
# 1172                1.3  inherited            inherited  female  24.0  ...
# 397                 6.8  self-made  founder non-finance    male  29.0  ...
# 1004               28.5  self-made  founder non-finance    male  29.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  \
# 1172              relation       1996.0          NaN     real estate
# 397                founder       2004.0          NaN        Facebook
# 1004               founder       2004.0          NaN        Facebook
#
#                       notes  notes2  \
# 1172  inherited from father     NaN
# 397                     NaN     NaN
# 1004                    NaN     NaN
#
#                                               source  \
# 1172        http://en.wikipedia.org/wiki/Perenna_Kei
# 397    http://en.wikipedia.org/wiki/Dustin_Moskovitz
# 1004  http://www.forbes.com/profile/mark-zuckerberg/
#
#                                                source_2  \
# 1172  http://www.loganestate.com/en/about.aspx?ftid=294
# 397     http://www.forbes.com/profile/dustin-moskovitz/
# 1004                                                NaN
#
#                                                source_3 source_4
# 1172                                                NaN      NaN
# 397   https://www.facebook.com/facebook/info?tab=pag...      NaN
# 1004                                                NaN      NaN
#
# [3 rows x 30 columns]

# %%
df.sort_values('age', ascending=False).head(3)
# Out:
#      year                    name  rank    citizenship countrycode  \
# 343  2014  David Rockefeller, Sr.   580  United States         USA
# 816  2014           Karl Wlaschek   305        Austria         AUT
# 836  2014          Kirk Kerkorian   328  United States         USA
#
#      networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 343                2.9  inherited            inherited   male  98.0  ...
# 816                4.8  self-made  founder non-finance   male  96.0  ...
# 836                4.5  self-made    self-made finance   male  96.0  ...
#
#     relationshiptocompany foundingdate gdpcurrentus        sourceofwealth  \
# 343              relation       1870.0          NaN          oil, banking
# 816               founder       1953.0          NaN                retail
# 836              investor       1924.0          NaN  casinos, investments
#
#                                                  notes  notes2  \
# 343  family made most of fortune in the late 19th a...     NaN
# 816                                                NaN     NaN
# 836                                  purchased in 1969     NaN
#
#                                              source  \
# 343  http://en.wikipedia.org/wiki/David_Rockefeller
# 816              http://en.wikipedia.org/wiki/BILLA
# 836     http://en.wikipedia.org/wiki/Kirk_Kerkorian
#
#                                           source_2  \
# 343      http://en.wikipedia.org/wiki/Standard_Oil
# 816     http://en.wikipedia.org/wiki/Karl_Wlaschek
# 836  http://www.forbes.com/profile/kirk-kerkorian/
#
#                                               source_3 source_4
# 343    http://en.wikipedia.org/wiki/Rockefeller_family      NaN
# 816  https://www.billa.at/Footer_Nav_Seiten/Geschic...      NaN
# 836  PROFILE: Las Vegas billionaire amassed his wea...      NaN
#
# [3 rows x 30 columns]

# %% [markdown]
# ## 10b) Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %%
df.sort_values('age', ascending=True).hist()
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'rank'}>,
#         <Axes: title={'center': 'networthusbillion'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'north'}>,
#         <Axes: title={'center': 'politicalconnection'}>],
#        [<Axes: title={'center': 'founder'}>,
#         <Axes: title={'center': 'foundingdate'}>,
#         <Axes: title={'center': 'gdpcurrentus'}>]], dtype=object)

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age
#
# It's more fun to do this in Altair as compared to matplotlib, but either is fine.

# %%
import matplotlib.pyplot as plt

# %%
df.plot (x='networthusbillion', y='age', kind='scatter')
# Out:
# <Axes: xlabel='networthusbillion', ylabel='age'>

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %%
richest.plot (x='name', y='networthusbillion', kind='bar')
# Out:
# <Axes: xlabel='name'>

# %% [markdown]
# ## 14) Read in the most recent data
#
# I copied and pasted the most recent data from [the original Bloomberg story](https://www.bloomberg.com/billionaires/) (it's in the page's source code), but it all was saved as JSON. Can you use pandas to read in `billionaires.json`?
#
# > **TIP:** If `pd.read_csv` reads a CSV and `pd.read_excel` reads an excel file... what reads in JSON?
# >
# > **TIP:** It's a lot less complicated than what we did in class.

# %%
pd.read_json ('billionaires.json')
